# %%
from allTopNaver import one_page_list

df = one_page_list(1, 1)
df = df.sort_values('현재가')
df
# Out:
# ['삼성전자', 57500]
# ['LG에너지솔루션', 399500]
# ['SK하이닉스', 94000]
# ['삼성바이오로직스', 825000]
# ['삼성전자우', 53500]
# ['현대차', 182500]
# ['NAVER', 233500]
# ['LG화학', 530000]
# ['삼성SDI', 541000]
# ['카카오', 72100]
# ['기아', 78800]
# ['셀트리온', 189000]
# ['삼성물산', 113000]
# ['현대모비스', 211500]
# ['POSCO홀딩스', 223000]
# ['KB금융', 45350]
# ['신한지주', 34000]
# ['SK이노베이션', 172500]
# ['SK', 206500]
# ['LG전자', 90200]
# ['카카오뱅크', 30900]
# ['한국전력', 21500]
# ['크래프톤', 245000]
# ['SK텔레콤', 54900]
# ['LG', 76000]
# ['삼성생명', 57800]
# ['SK바이오사이언스', 150000]
# ['HMM', 23500]
# ['두산에너빌리티', 17800]
# ['LG생활건강', 720000]
# ['KT&G', 81000]
# ['하나금융지주', 34800]
# ['현대중공업', 115000]
# ['S-Oil', 90600]
# ['삼성에스디에스', 130500]
# ['삼성전기', 132000]
# ['KT', 36950]
# ['삼성화재', 197000]
# ['대한항공', 24850]
# ['카카오페이', 68100]
# ['고려아연', 452000]
# ['포스코케미칼', 110000]
# ['우리금융지주', 11300]
# ['엔씨소프트', 367500]
# ['LG이노텍', 339500]
# ['아모레퍼시픽', 134500]
# ['현대글로비스', 182500]
# ['하이브', 163500]
# ['기업은행', 9030]
# ['한화솔루션', 32950]
#           종목명     현재가
# ...
